# %%
# !wget 'https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg'
# Out:
# --2024-10-14 03:23:10--  https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg
# Resolving tractive.com (tractive.com)... 13.35.7.27, 13.35.7.42, 13.35.7.2, ...
# Connecting to tractive.com (tractive.com)|13.35.7.27|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 113570 (111K) [image/jpeg]
# Saving to: ‘puppy-care-guide-for-new-parents.jpg’
#
# puppy-care-guide-fo 100%[===================>] 110.91K   248KB/s    in 0.4s
#
# 2024-10-14 03:23:12 (248 KB/s) - ‘puppy-care-guide-for-new-parents.jpg’ saved [113570/113570]

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
image = mpimg.imread('puppy-care-guide-for-new-parents.jpg')
plt.imshow(image)
plt.show()

# %%
type(image)
# Out:
# numpy.ndarray

# %%
print(image.shape)
# Out:
# (1365, 2048, 3)

# %%
print(image)
# Out:
# [[[147 182   0]
#   [147 182   0]
#   [147 182   0]
#   ...
#   [128 148   0]
#   [128 148   0]
#   [128 148   0]]
#
#  [[146 181   0]
#   [146 181   0]
#   [147 182   0]
#   ...
#   [128 148   0]
#   [128 148   0]
#   [128 148   0]]
#
#  [[145 180   0]
#   [145 180   0]
#   [145 180   0]
#   ...
#   [128 148   0]
#   [128 148   0]
#   [128 148   0]]
#
#  ...
#
#  [[ 76  69  25]
#   [ 76  69  25]
#   [ 75  68  24]
#   ...
#   [135 106  38]
#   [135 106  38]
#   [135 106  38]]
#
#  [[ 76  69  25]
#   [ 76  69  25]
#   [ 75  68  24]
#   ...
#   [135 106  38]
#   [135 106  38]
#   [135 106  38]]
#
#  [[ 76  69  25]
#   [ 76  69  25]
#   [ 75  68  24]
#   ...
#   [135 106  38]
#   [135 106  38]
#   [135 106  38]]]

# %%
image_plot = plt.imshow(image)
plt.show()

# %%
from PIL import Image

# %%
image= Image.open('/content/puppy-care-guide-for-new-parents.jpg')

# %%
image_resize = image.resize((200,200))

# %%
print(image_resize)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x79E549564F10>

# %%
image_resize.save('dog_resized.jpg')

# %%
image_res= mpimg.imread('/content/dog_resized.jpg')
image_res_plot = plt.imshow(image_res)
plt.show()

# %%
type(image_res)
# Out:
# numpy.ndarray

# %%
print(image_res.shape)
# Out:
# (200, 200, 3)

# %%
import cv2

# %%
image_cv = cv2.imread('/content/puppy-care-guide-for-new-parents.jpg')

# %%
type(image_cv)
# Out:
# numpy.ndarray

# %%
image_cv.shape
# Out:
# (1365, 2048, 3)

# %%
grayscale_image= cv2.cvtColor(image_cv, cv2.COLOR_BGR2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (1365, 2048)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=2048x1365>

# %%
cv2.resize(grayscale_image, (200,200))
# Out:
# array([[149, 157, 157, ..., 137, 129, 125],
#        [140, 145, 145, ..., 136, 128, 128],
#        [140, 136, 134, ..., 134, 130, 130],
#        ...,
#        [ 59,  52,  40, ...,  96, 101, 106],
#        [ 57,  52,  43, ...,  97, 103, 106],
#        [ 62,  52,  49, ..., 102, 107, 107]], dtype=uint8)

# %%
cv2.imwrite('grayscale_dog_image.jpg', grayscale_image)
# Out:
# True
